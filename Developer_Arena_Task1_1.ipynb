# %% [markdown]
# Hello World Program

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# Variables for Personal Information

# %%
name = "Aditya Kamble"
age = 21
city = "Mumbai"

print("Name:", name)
print("Age:", age)
print("City:", city)
# Out:
# Name: Aditya Kamble
# Age: 21
# City: Mumbai

# %% [markdown]
# Basic Math Calculations

# %%
a = int(input("Enter the first number"))
b = int(input("Enter a  second number"))

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Power:", a ** b)
# Out:
# Enter the first number 6
# Enter a  second number 5
# Addition: 11
# Subtraction: 1
# Multiplication: 30
# Division: 1.2
# Power: 7776

# %% [markdown]
# List of Favorite Foods

# %%
foods = ["Vadapav", "Samosa Pav", "SevPuri", "Chinese Bhel"]

print("My favourite foods:")
print(foods)

print("First food:", foods[0])
print("Last food:", foods[-1])
# Out:
# My favourite foods:
# ['Vadapav', 'Samosa Pav', 'SevPuri', 'Chinese Bhel']
# First food: Vadapav
# Last food: Chinese Bhel

# %% [markdown]
# Building Bio-Data Program

# %%
name = "Aditya Kamble"
age = 21
city = "Mumbai"
hobby = "Coding"

print(" BIO DATA ")
print("Name:", name)
print("Age:", age)
print("City:", city)
print("Hobby:", hobby)
# Out:
#  BIO DATA
# Name: Aditya Kamble
# Age: 21
# City: Mumbai
# Hobby: Coding

# %% [markdown]
# Personal Introduction Program

# %%
name = input("Enter your name: ")
age = input("Enter your age: ")
hobby = input("Enter your hobby: ")

print("\n Welcome Message ")
print(f"Hello everyone . My name is {name}.I am {age} years old and I love {hobby}.")
print("Nice to meet you all! 😊")
# Out:
# Enter your name:  Aditya Kamble
# Enter your age:  21
# Enter your hobby:  Coding
#  Welcome Message
# Hello everyone . My name is Aditya Kamble.I am 21 years old and I love Coding.
# Nice to meet you all! 😊
